# %%
import numpy as np
from numpy import array
import pandas as pd
from pandas import DataFrame

# %%
df = pd.read_csv('/home/lzy/lab_env/Project/平望日频时频/处理/PingwangDaily+2.csv',index_col=0)
print(type(df))
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (3913, 389)

# %%
# df = pd.read_csv('20221021X_value_pingwang.csv',index_col=0)
# print(type(df))
# df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index(['TM(t_0)', 'Z'', '0', '1', '2', '3', '4', '5', '6', '7',
#        ...
#        '369', '370', '371', '372', '373', '374', '375', '376', '377', '378'],
#       dtype='object', length=381)

# %% [markdown]
# ### 时频

# %%
columns = []
columns_name_6240 = []
columns_name_504 = []

# %% [markdown]
# ### 日频

# %%
columns = []
columns_name_10x33 = []
columns_name_29x2 = []

# %%
'''['Z', 
1       'DRP(63001000)', 'DRP(63203000)','DRP(63204401)','DRP(63204450)','DRP(63204600)',
        'DRP(63204650)','DRP(63204800)','DRP(63204850)','DRP(63205350)','DRP(63300800)',
        'DRP(63301150)','DRP(63301600)','DRP(63303600)','DRP(63304800)','DRP(63305200)',
        'DRP(63305800)','DRP(63309200)','DRP(63309600)','DRP(63310600)','DRP(63403200)',
        'DRP(63403500)',
        'UPZ(太浦闸)','DWZ(太浦闸)','TGTQ(太浦闸)','TDZ(米市渡潮位)']'''
# Out:
# "['Z', \n1       'DRP(63001000)', 'DRP(63203000)','DRP(63204401)','DRP(63204450)','DRP(63204600)',\n        'DRP(63204650)','DRP(63204800)','DRP(63204850)','DRP(63205350)','DRP(63300800)',\n        'DRP(63301150)','DRP(63301600)','DRP(63303600)','DRP(63304800)','DRP(63305200)',\n        'DRP(63305800)','DRP(63309200)','DRP(63309600)','DRP(63310600)','DRP(63403200)',\n        'DRP(63403500)',\n        'UPZ(太浦闸)','DWZ(太浦闸)','TGTQ(太浦闸)','TDZ(米市渡潮位)']"

# %% [markdown]
# ### 时频

# %%
for i in range(1, 241):
    columns_name_6240.extend(['Z(t'+str(i-240)+')', 
                            'DYP-63001000(t'+str(i-240)+')', 'DYP-63203000(t'+str(i-240)+')', 'DYP-63204401(t'+str(i-240)+')', 'DYP-63204450(t'+str(i-240)+')', 'DYP-63204600(t'+str(i-240)+')', 
                            'DYP-63204650(t'+str(i-240)+')', 'DYP-63204800(t'+str(i-240)+')', 'DYP-63204850(t'+str(i-240)+')', 'DYP-63205350(t'+str(i-240)+')', 'DYP-63300800(t'+str(i-240)+')', 
                            'DYP-63301150(t'+str(i-240)+')', 'DYP-63301600(t'+str(i-240)+')', 'DYP-63303600(t'+str(i-240)+')', 'DYP-63304800(t'+str(i-240)+')', 'DYP-63305200(t'+str(i-240)+')', 
                            'DYP-63305800(t'+str(i-240)+')', 'DYP-63309200(t'+str(i-240)+')', 'DYP-63309600(t'+str(i-240)+')',  'DYP-63310600(t'+str(i-240)+')', 'DYP-63403200(t'+str(i-240)+')', 
                            'DYP-63403500(t'+str(i-240)+')', 
                            'UPZ(t'+str(i-240)+')', 'DWZ(t'+str(i-240)+')', 'TGTQ(t'+str(i-240)+')', 'TDZ(t'+str(i-240)+')'])

len(columns_name_6240)

# %% [markdown]
# ### 日频

# %%
for i in range(1, 11):
    columns_name_10x33.extend(['Z(t'+str(i-10)+')', 
                            'DYP-63001000(t'+str(i-10)+')', 'DYP-63203000(t'+str(i-10)+')', 'DYP-63204401(t'+str(i-10)+')', 'DYP-63204450(t'+str(i-10)+')', 'DYP-63204600(t'+str(i-10)+')', 
                            'DYP-63204650(t'+str(i-10)+')', 'DYP-63204800(t'+str(i-10)+')', 'DYP-63204850(t'+str(i-10)+')', 'DYP-63205350(t'+str(i-10)+')', 'DYP-63300800(t'+str(i-10)+')', 
                            'DYP-63301150(t'+str(i-10)+')', 'DYP-63301600(t'+str(i-10)+')', 'DYP-63303600(t'+str(i-10)+')', 'DYP-63304800(t'+str(i-10)+')', 'DYP-63305200(t'+str(i-10)+')', 
                            'DYP-63305800(t'+str(i-10)+')', 'DYP-63309200(t'+str(i-10)+')', 'DYP-63309600(t'+str(i-10)+')',  'DYP-63310600(t'+str(i-10)+')', 'DYP-63403200(t'+str(i-10)+')', 
                            'DYP-63403500(t'+str(i-10)+')', 
                            'UPZ(t'+str(i-10)+')', 'DWZ(t'+str(i-10)+')', 'TGTQ(t'+str(i-10)+')', 'TDZ(t'+str(i-10)+')'])

len(columns_name_10x33)
# Out:
# 6240

# %%
columns_name_6240
# Out:
# ['Z(t-239)',
#  'DYP-63001000(t-239)',
#  'DYP-63203000(t-239)',
#  'DYP-63204401(t-239)',
#  'DYP-63204450(t-239)',
#  'DYP-63204600(t-239)',
#  'DYP-63204650(t-239)',
#  'DYP-63204800(t-239)',
#  'DYP-63204850(t-239)',
#  'DYP-63205350(t-239)',
#  'DYP-63300800(t-239)',
#  'DYP-63301150(t-239)',
#  'DYP-63301600(t-239)',
#  'DYP-63303600(t-239)',
#  'DYP-63304800(t-239)',
#  'DYP-63305200(t-239)',
#  'DYP-63305800(t-239)',
#  'DYP-63309200(t-239)',
#  'DYP-63309600(t-239)',
#  'DYP-63310600(t-239)',
#  'DYP-63403200(t-239)',
#  'DYP-63403500(t-239)',
#  'UPZ(t-239)',
#  'DWZ(t-239)',
#  'TGTQ(t-239)',
#  'TDZ(t-239)',
#  'Z(t-238)',
#  'DYP-63001000(t-238)',
#  'DYP-63203000(t-238)',
#  'DYP-63204401(t-238)',
#  'DYP-63204450(t-238)',
#  'DYP-63204600(t-238)',
#  'DYP-63204650(t-238)',
#  'DYP-63204800(t-238)',
#  'DYP-63204850(t-238)',
#  'DYP-63205350(t-238)',
#  'DYP-63300800(t-238)',
#  'DYP-63301150(t-238)',
#  'DYP-63301600(t-238)',
#  'DYP-63303600(t-238)',
# ...

# %%
columns_name_10x33

# %%
# for i in range(1, 11):
#     columns_name_350.extend(['Z(t'+str(i-10)+')', 'Q(t'+str(i-10)+')', 'DYP-63001000(t'+str(i-10)+')', 'DYP-63203000(t'+str(i-10)+')', 'DYP-63204401(t'+str(i-10)+')', 
#                             'DYP-63204450(t'+str(i-10)+')', 'DYP-63204600(t'+str(i-10)+')', 'DYP-63204650(t'+str(i-10)+')', 'DYP-63204800(t'+str(i-10)+')', 'DYP-63204850(t'+str(i-10)+')', 
#                             'DYP-63205350(t'+str(i-10)+')', 'DYP-63300800(t'+str(i-10)+')', 'DYP-63301150(t'+str(i-10)+')', 'DYP-63301600(t'+str(i-10)+')', 'DYP-63303400(t'+str(i-10)+')', 
#                             'DYP-63303600(t'+str(i-10)+')', 'DYP-63304400(t'+str(i-10)+')', 'DYP-63304800(t'+str(i-10)+')', 'DYP-63305200(t'+str(i-10)+')', 'DYP-63305800(t'+str(i-10)+')', 
#                             'DYP-63307200(t'+str(i-10)+')', 'DYP-63307800(t'+str(i-10)+')', 'DYP-63309200(t'+str(i-10)+')', 'DYP-63309600(t'+str(i-10)+')', 'DYP-63310400(t'+str(i-10)+')', 
#                             'DYP-63310600(t'+str(i-10)+')', 'DYP-63320600(t'+str(i-10)+')', 'DYP-63403200(t'+str(i-10)+')', 'DYP-63403500(t'+str(i-10)+')', 'DYP-63403600(t'+str(i-10)+')', 
#                             'DYP-63404900(t'+str(i-10)+')', 'UPZ(t'+str(i-10)+')', 'DWZ(t'+str(i-10)+')', 'TGTQ(t'+str(i-10)+')', 'TDZ(t'+str(i-10)+')'])

# columns_name_350

# %%
for i in range(1, 25):
    columns_name_504.extend([ 
                            'DYP+63001000(t+'+str(i)+')', 'DYP+63203000(t+'+str(i)+')', 'DYP+63204401(t+'+str(i)+')', 'DYP+63204450(t+'+str(i)+')', 'DYP+63204600(t+'+str(i)+')', 
                            'DYP+63204650(t+'+str(i)+')', 'DYP+63204800(t+'+str(i)+')', 'DYP+63204850(t+'+str(i)+')', 'DYP+63205350(t+'+str(i)+')', 'DYP+63300800(t+'+str(i)+')', 
                            'DYP+63301150(t+'+str(i)+')', 'DYP+63301600(t+'+str(i)+')', 'DYP+63303600(t+'+str(i)+')', 'DYP+63304800(t+'+str(i)+')', 'DYP+63305200(t+'+str(i)+')', 
                            'DYP+63305800(t+'+str(i)+')', 'DYP+63309200(t+'+str(i)+')', 'DYP+63309600(t+'+str(i)+')',  'DYP+63310600(t+'+str(i)+')', 'DYP+63403200(t+'+str(i)+')', 
                            'DYP+63403500(t+'+str(i)+')', 
                            ])

len(columns_name_504)
# Out:
# 504

# %%
columns_name_504
# Out:
# ['DYP+63001000(t+1)',
#  'DYP+63203000(t+1)',
#  'DYP+63204401(t+1)',
#  'DYP+63204450(t+1)',
#  'DYP+63204600(t+1)',
#  'DYP+63204650(t+1)',
#  'DYP+63204800(t+1)',
#  'DYP+63204850(t+1)',
#  'DYP+63205350(t+1)',
#  'DYP+63300800(t+1)',
#  'DYP+63301150(t+1)',
#  'DYP+63301600(t+1)',
#  'DYP+63303600(t+1)',
#  'DYP+63304800(t+1)',
#  'DYP+63305200(t+1)',
#  'DYP+63305800(t+1)',
#  'DYP+63309200(t+1)',
#  'DYP+63309600(t+1)',
#  'DYP+63310600(t+1)',
#  'DYP+63403200(t+1)',
#  'DYP+63403500(t+1)',
#  'DYP+63001000(t+2)',
#  'DYP+63203000(t+2)',
#  'DYP+63204401(t+2)',
#  'DYP+63204450(t+2)',
#  'DYP+63204600(t+2)',
#  'DYP+63204650(t+2)',
#  'DYP+63204800(t+2)',
#  'DYP+63204850(t+2)',
#  'DYP+63205350(t+2)',
#  'DYP+63300800(t+2)',
#  'DYP+63301150(t+2)',
#  'DYP+63301600(t+2)',
#  'DYP+63303600(t+2)',
#  'DYP+63304800(t+2)',
#  'DYP+63305200(t+2)',
#  'DYP+63305800(t+2)',
#  'DYP+63309200(t+2)',
#  'DYP+63309600(t+2)',
#  'DYP+63310600(t+2)',
#  'DYP+63403200(t+2)',
# ...

# %%
# columns_name_29 = ['DYP-63001000(t+1)',
#  'DYP-63203000(t+1)',
#  'DYP-63204401(t+1)',
#  'DYP-63204450(t+1)',
#  'DYP-63204600(t+1)',
#  'DYP-63204650(t+1)',
#  'DYP-63204800(t+1)',
#  'DYP-63204850(t+1)',
#  'DYP-63205350(t+1)',
#  'DYP-63300800(t+1)',
#  'DYP-63301150(t+1)',
#  'DYP-63301600(t+1)',
#  'DYP-63303400(t+1)',
#  'DYP-63303600(t+1)',
#  'DYP-63304400(t+1)',
#  'DYP-63304800(t+1)',
#  'DYP-63305200(t+1)',
#  'DYP-63305800(t+1)',
#  'DYP-63307200(t+1)',
#  'DYP-63307800(t+1)',
#  'DYP-63309200(t+1)',
#  'DYP-63309600(t+1)',
#  'DYP-63310400(t+1)',
#  'DYP-63310600(t+1)',
#  'DYP-63320600(t+1)',
#  'DYP-63403200(t+1)',
#  'DYP-63403500(t+1)',
#  'DYP-63403600(t+1)',
#  'DYP-63404900(t+1)',]

# %%
columns = columns_name_6240 + columns_name_504
print(len(columns))
# Out:
# 6744

# %%
columns.insert(0,'Z\'')
columns.insert(0,'TM(t_0)')

# %%
len(columns)
# Out:
# 6746

# %%
df.columns
# Out:
# Index(['TM(t_0)', 'Z'', 'Z(t-239)', 'DYP-63001000(t-239)',
#        'DYP-63203000(t-239)', 'DYP-63204401(t-239)', 'DYP-63204450(t-239)',
#        'DYP-63204600(t-239)', 'DYP-63204650(t-239)', 'DYP-63204800(t-239)',
#        ...
#        'DYP+63301600(t+24)', 'DYP+63303600(t+24)', 'DYP+63304800(t+24)',
#        'DYP+63305200(t+24)', 'DYP+63305800(t+24)', 'DYP+63309200(t+24)',
#        'DYP+63309600(t+24)', 'DYP+63310600(t+24)', 'DYP+63403200(t+24)',
#        'DYP+63403500(t+24)'],
#       dtype='object', length=6746)

# %%
df.to_csv('alter_columns.csv')
